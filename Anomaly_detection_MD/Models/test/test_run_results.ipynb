# %% [markdown]
# **Name:**
#   **Majid Jafari**

# %% [markdown]
# **Step 1:**
#
# -All you need to do is to run the following, it creates a new conda environment in the "envs" directory with the name "envs" and installs all the packages specified in the requirements.yml file (all the packages that you need to run the program). It then activates the newly created environment.
#
# `conda env create --prefix ./envs --file requirements.yml`
#
# `conda activate ./envs`
#
# Make sure you put the requirements.yml file in the current directory (repo directory) so conda can find it.

# %%
# %run run.py
# Out:
# Directory run_2022-12-03 is created.
# eq.in is copied to the run_2022-12-03 directory!
# heat.in is copied to the run_2022-12-03 directory!
# md.in is copied to the run_2022-12-03 directory!
# min.in is copied to the run_2022-12-03 directory!
# protein.pdb is copied to the run_2022-12-03 directory!
# tleap.in is copied to the run_2022-12-03 directory!
# Preparing your system using tleap...
# Running ParMed to get your system information...
# Running the minimization step using sander...
# The minimization step is finished. Running the heating step...
# The heating step is finished. Running the equilibration step...
# The equilibration step is finished. Running the production step...
# The simulation is finished.

# %% [markdown]
# **Step 2:**
#
# -The next step is to analyze the simulations. We can do that by running the following command line which uses CPPTRAJ to perform the analysis and get the RMSD data.

# %%
# %run analysis.py
# Out:
# Directory analysis_2022-12-03 is created.
# The trajecotry file is being moved to the analysis_2022-12-03 directory!
# The restart file is being moved to the analysis_2022-12-03 directory!
# The parameter file is copied to the analysis_2022-12-03 directory!
# The rmsd.txt file is successfully created.
# The rmsd.agr file is successfully created.

# %% [markdown]
# **Step 3:**
#
# -Last but not least, we can run the following to detect anomalies in the RMSD data:

# %%
# %run anomalies_detection.py
# Out:
# The RMSD file is being copied to the /mnt/e/MSU/Fall2022/CMSE802/project/scripts/test_software directory!
# The percentage of anomalies in the data is: 26.00%

# %% [markdown]
# **Results:**
#
# -The left panel above shows the original RMSD data obtained from MD simulations. The panel on the right, highlights the anomalies detected in the data using the `Isolation Forest` algorithm.
#
# As you can see, anomalies make **26%** of the data and because **the majority** of the data points are normal (74%) we can say the model is correct and the simulations look normal. The worst anomalies are highlighted in different color (See the green cross sign in the right panel). The scripts create a `detected_anomalies.txt` file in the current directory, containing the anomaly values. Also, an image named `detected_anomalies.tif` with high quality will be created in the working directory, showing the above figure.
#
# In general, the results show that we can continue to do our MD simulation using the input parameters we specified for this simulation.
#
# I have provided the `main.py` script in the git repository, so the user should just run this script and it will do all the above three steps. I explained all the details in the README.md file in my repository.
